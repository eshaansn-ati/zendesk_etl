# %%
import json

file_path = "../data/transform/fields/ticket_fields_1764932460.json"
with open(file_path, "r", encoding="utf-8") as f:
    fields = json.load(f)
names = [field["title"] for field in fields if "title" in field]
print("Field names:")
for name in names:
    print(name)
# Out:
# Field names:
# Subject
# Description
# Status
# Type
# Priority
# Group
# Assignee
# Ticket status
# Approval status
# Categorization
# Sub_Category
# Product Area Hardware
# Ticket_Type
# SLA Category
# CSM Involved
# Resolver Team
# Requestor Group
# Reporting Medium
# End Time
# Start Time
# Region
# Amr Type
# Bot Number
# Alert_fm_tag
# Alert_ ip_changed
# customer
# Alert_display_message
# Alert_ message
# Alert_ module
# Alert_ parking_mode
# Alert_ sw_tag
# Alert_code
# Alert_compatible_sherpa_tags
# Alert_id
# Alert_ incident_id
# Alert_ site
# Alert_ sub_module
# Alert_entity_name
# Alert_heading
# Alert_ location
# Alert_ recovery_message
# Alert_ sw_date
# Alert_type
# Alert_fm_client_name
# Alert_Duplicate
# Dev Ticket
# Periskope_ID
# Requestor_Phone_Number
# Whatsapp_Group_Message
# Product Area Software
# Slack Ticket
# Service Ticket Required
# Resolution type
# What would you want the Service Engineer to check?
# Bot Number
# AMR Number
# Fm Version
# FM Issue Category
# First_response_Slack_Ticket_Minutes
# Upgrade Date
# Bot Back to Production
# Number of Minutes Downtime
# RCA work Required
# Engineering required
# Parent_ticket
# Child_Ticket_ID
